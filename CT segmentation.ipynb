# %%
import os
import glob
import zipfile
import functools

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['axes.grid'] = False
mpl.rcParams['figure.figsize'] = (12,12)

from sklearn.model_selection import train_test_split
import matplotlib.image as mpimg
import pandas as pd
from PIL import Image

import tensorflow as tf
import tensorflow.contrib as tfcontrib
from tensorflow.python.keras import layers
from tensorflow.python.keras import losses
from tensorflow.python.keras import models
from tensorflow.python.keras import backend as K  

from __future__ import absolute_import, division, print_function, unicode_literals
AUTOTUNE = tf.data.experimental.AUTOTUNE
import pathlib

# %%
#def get_data(competition):
#   load_data_from_dir(competition, 'png0FSNYCKQ')
#   load_data_from_dir(competition, 'png0FSNYCKQ-mark')



competition_name = r'C:\Users\yan\Documents\CT'
#get_data(competition_name)

img_dir = os.path.join(competition_name, "\png0FSNYCKQ")
label_dir = os.path.join(competition_name, "\png0FSNYCKQ-mark")

# %% [markdown]
# 设置数据

# %%
x_train_filenames = []
y_train_filenames = []
i=0
for i in range(300):
   x_train_filenames.append(os.path.join(img_dir, "{}_i.png".format("%04d" % i)))
   y_train_filenames.append(os.path.join(label_dir, "{}_i.png".format("%04d" % i)))

# %%
x_train_filenames, x_val_filenames, y_train_filenames, y_val_filenames = \
                    train_test_split(x_train_filenames, y_train_filenames, test_size=0.2, random_state=42)

# %%
num_train_examples = len(x_train_filenames)
num_val_examples = len(x_val_filenames)

print("Number of training examples: {}".format(num_train_examples))
print("Number of validation examples: {}".format(num_val_examples))
# Out:
# Number of training examples: 240
# Number of validation examples: 60

# %% [markdown]
# 看一下数据形式

# %%
x_train_filenames[:10]
# Out:
# ['C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ\\0232_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ\\0059_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ\\0006_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ\\0185_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ\\0173_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ\\0030_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ\\0022_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ\\0256_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ\\0056_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ\\0186_i.png']

# %%
y_train_filenames[:10]
# Out:
# ['C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ-mark\\0232_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ-mark\\0059_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ-mark\\0006_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ-mark\\0185_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ-mark\\0173_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ-mark\\0030_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ-mark\\0022_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ-mark\\0256_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ-mark\\0056_i.png',
#  'C:\\Users\\yan\\Documents\\CT\\png0FSNYCKQ-mark\\0186_i.png']

# %%
display_num = 5

r_choices = np.random.choice(num_train_examples, display_num)

plt.figure(figsize=(10, 15))
for i in range(0, display_num * 2, 2):
  img_num = r_choices[i // 2]
  x_pathname = x_train_filenames[img_num]
  y_pathname = y_train_filenames[img_num]
  
  plt.subplot(display_num, 2, i + 1)
  #plt.imshow(mpimg.imread(x_pathname))
  plt.imshow(Image.open(x_pathname))
  plt.title("Original Image")
  
  example_labels = Image.open(y_pathname)
  label_vals = np.unique(example_labels)
  
  plt.subplot(display_num, 2, i + 2)
  plt.imshow(example_labels)
  plt.title("Masked Image")  
  
plt.suptitle("Examples of Images and their Masks")
plt.show()

# %%
img_shape = (512, 512, 8)
batch_size = 3
epochs = 5

# %%
def _process_pathnames(fname, label_path):
  # We map this function onto each pathname pair  
  img_str = tf.read_file(fname)
  img = tf.image.decode_jpeg(img_str, channels=3)

  label_img_str = tf.read_file(label_path)
  # These are gif images so they return as (num_frames, h, w, c)
  label_img = tf.image.decode_gif(label_img_str)[0]
  # The label image should only have values of 1 or 0, indicating pixel wise
  # object (car) or not (background). We take the first channel only. 
  label_img = label_img[:, :, 0]
  label_img = tf.expand_dims(label_img, axis=-1)
  return img, label_img

# %%
def shift_img(output_img, label_img, width_shift_range, height_shift_range):
  """This fn will perform the horizontal or vertical shift"""
  if width_shift_range or height_shift_range:
      if width_shift_range:
        width_shift_range = tf.random_uniform([], 
                                              -width_shift_range * img_shape[1],
                                              width_shift_range * img_shape[1])
      if height_shift_range:
        height_shift_range = tf.random_uniform([],
                                               -height_shift_range * img_shape[0],
                                               height_shift_range * img_shape[0])
      # Translate both 
      output_img = tfcontrib.image.translate(output_img,
                                             [width_shift_range, height_shift_range])
      label_img = tfcontrib.image.translate(label_img,
                                             [width_shift_range, height_shift_range])
  return output_img, label_img

# %%
def flip_img(horizontal_flip, tr_img, label_img):
  if horizontal_flip:
    flip_prob = tf.random_uniform([], 0.0, 1.0)
    tr_img, label_img = tf.cond(tf.less(flip_prob, 0.5),
                                lambda: (tf.image.flip_left_right(tr_img), tf.image.flip_left_right(label_img)),
                                lambda: (tr_img, label_img))
  return tr_img, label_img

# %%
def _augment(img,
             label_img,
             resize=[512,512],  # Resize the image to some size e.g. [256, 256]
             scale=1,  # Scale image e.g. 1 / 255.
             hue_delta=0,  # Adjust the hue of an RGB image by random factor
             horizontal_flip=False,  # Random left right flip,
             width_shift_range=0,  # Randomly translate the image horizontally
             height_shift_range=0):  # Randomly translate the image vertically 
  if resize is not None:
    # Resize both images
    label_img = tf.image.resize_images(label_img, resize)
    img = tf.image.resize_images(img, resize)
  
  if hue_delta:
    img = tf.image.random_hue(img, hue_delta)
  
  img, label_img = flip_img(horizontal_flip, img, label_img)
  img, label_img = shift_img(img, label_img, width_shift_range, height_shift_range)
  label_img = tf.to_float(label_img) * scale
  img = tf.to_float(img) * scale 
  return img, label_img

# %%
def get_baseline_dataset(filenames, 
                         labels,
                         preproc_fn=functools.partial(_augment),
                         threads=5, 
                         batch_size=batch_size,
                         shuffle=True):           
  num_x = len(filenames)
  # Create a dataset from the filenames and labels
  dataset = tf.data.Dataset.from_tensor_slices((filenames, labels))
  # Map our preprocessing function to every element in our dataset, taking
  # advantage of multithreading
  dataset = dataset.map(_process_pathnames, num_parallel_calls=threads)
  if preproc_fn.keywords is not None and 'resize' not in preproc_fn.keywords:
    assert batch_size == 1, "Batching images must be of the same size"

  dataset = dataset.map(preproc_fn, num_parallel_calls=threads)
  
  if shuffle:
    dataset = dataset.shuffle(num_x)
  
  
  # It's necessary to repeat our data for all epochs 
  dataset = dataset.repeat().batch(batch_size)
  return dataset

# %% [markdown]
# Set up train and validation datasets

# %%
tr_cfg = {
    'resize': [img_shape[0], img_shape[1]],
    'scale': 1 / 255.,
    'hue_delta': 0,
    'horizontal_flip': False,
    'width_shift_range': 0,
    'height_shift_range': 0
}
tr_preprocessing_fn = functools.partial(_augment, **tr_cfg)

# %%
val_cfg = {
    'resize': [img_shape[0], img_shape[1]],
    'scale': 1/255,
}
val_preprocessing_fn = functools.partial(_augment, **val_cfg)

# %%
train_ds = get_baseline_dataset(x_train_filenames,
                                y_train_filenames,
                                preproc_fn=tr_preprocessing_fn,
                                batch_size=batch_size)
val_ds = get_baseline_dataset(x_val_filenames,
                              y_val_filenames, 
                              preproc_fn=val_preprocessing_fn,
                              batch_size=batch_size)

# %%
temp_ds = get_baseline_dataset(x_train_filenames, 
                               y_train_filenames,
                               preproc_fn=tr_preprocessing_fn,
                               batch_size=1,
                               shuffle=False)
# Let's examine some of these augmented images
data_aug_iter = temp_ds.make_one_shot_iterator()
next_element = data_aug_iter.get_next()
with tf.Session() as sess: 
  batch_of_imgs, label = sess.run(next_element)

  # Running next element in our graph will produce a batch of images
  plt.figure(figsize=(10, 10))
  img = batch_of_imgs[0]

  plt.subplot(1, 2, 1)
  plt.imshow(img)

  plt.subplot(1, 2, 2)
  plt.imshow(label[0, :, :, 0])
  plt.show()

# %%
def conv_block(input_tensor, num_filters):
  encoder = layers.Conv2D(num_filters, (3, 3), padding='same')(input_tensor)
  encoder = layers.BatchNormalization()(encoder)
  encoder = layers.Activation('relu')(encoder)
  encoder = layers.Conv2D(num_filters, (3, 3), padding='same')(encoder)
  encoder = layers.BatchNormalization()(encoder)
  encoder = layers.Activation('relu')(encoder)
  return encoder

def encoder_block(input_tensor, num_filters):
  encoder = conv_block(input_tensor, num_filters)
  encoder_pool = layers.MaxPooling2D((2, 2), strides=(2, 2))(encoder)
  
  return encoder_pool, encoder

def decoder_block(input_tensor, concat_tensor, num_filters):
  decoder = layers.Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding='same')(input_tensor)
  decoder = layers.concatenate([concat_tensor, decoder], axis=-1)
  decoder = layers.BatchNormalization()(decoder)
  decoder = layers.Activation('relu')(decoder)
  decoder = layers.Conv2D(num_filters, (3, 3), padding='same')(decoder)
  decoder = layers.BatchNormalization()(decoder)
  decoder = layers.Activation('relu')(decoder)
  decoder = layers.Conv2D(num_filters, (3, 3), padding='same')(decoder)
  decoder = layers.BatchNormalization()(decoder)
  decoder = layers.Activation('relu')(decoder)
  return decoder

# %%
inputs = layers.Input(shape=img_shape)
# 256

encoder0_pool, encoder0 = encoder_block(inputs, 32)
# 128

encoder1_pool, encoder1 = encoder_block(encoder0_pool, 64)
# 64

encoder2_pool, encoder2 = encoder_block(encoder1_pool, 128)
# 32

encoder3_pool, encoder3 = encoder_block(encoder2_pool, 256)
# 16

encoder4_pool, encoder4 = encoder_block(encoder3_pool, 512)
# 8

center = conv_block(encoder4_pool, 1024)
# center

decoder4 = decoder_block(center, encoder4, 512)
# 16

decoder3 = decoder_block(decoder4, encoder3, 256)
# 32

decoder2 = decoder_block(decoder3, encoder2, 128)
# 64

decoder1 = decoder_block(decoder2, encoder1, 64)
# 128

decoder0 = decoder_block(decoder1, encoder0, 32)
# 256

outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(decoder0)
# Out:
# WARNING:tensorflow:From C:\Users\yan\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model = models.Model(inputs=[inputs], outputs=[outputs])

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1.
    # Flatten
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)
    return score

# %%
def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

# %%
def bce_dice_loss(y_true, y_pred):
    loss = losses.binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss

# %%
model.compile(optimizer='adam', loss=bce_dice_loss, metrics=[dice_loss])

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 8)  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 32) 2336        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1 (BatchNo (None, 512, 512, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 512, 512, 32) 0           batch_normalization_v1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 32) 9248        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_1 (Batch (None, 512, 512, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 512, 512, 32) 0           batch_normalization_v1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 32) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_2 (Batch (None, 256, 256, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 64) 0           batch_normalization_v1_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 64) 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_3 (Batch (None, 256, 256, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 256, 64) 0           batch_normalization_v1_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_4 (Batch (None, 128, 128, 128 512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 128 0           batch_normalization_v1_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 128 147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_5 (Batch (None, 128, 128, 128 512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 128 0           batch_normalization_v1_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_6 (Batch (None, 64, 64, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           batch_normalization_v1_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_7 (Batch (None, 64, 64, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 256)  0           batch_normalization_v1_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_8 (Batch (None, 32, 32, 512)  2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 512)  0           batch_normalization_v1_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 512)  2359808     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_9 (Batch (None, 32, 32, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 512)  0           batch_normalization_v1_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 512)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 1024) 4719616     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_10 (Batc (None, 16, 16, 1024) 4096        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 1024) 0           batch_normalization_v1_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 1024) 9438208     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_11 (Batc (None, 16, 16, 1024) 4096        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 1024) 0           batch_normalization_v1_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 512)  2097664     activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           activation_9[0][0]
#                                                                  conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_12 (Batc (None, 32, 32, 1024) 4096        concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 1024) 0           batch_normalization_v1_12[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  4719104     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_13 (Batc (None, 32, 32, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 512)  0           batch_normalization_v1_13[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 512)  2359808     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_14 (Batc (None, 32, 32, 512)  2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 512)  0           batch_normalization_v1_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  524544      activation_14[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           activation_7[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_15 (Batc (None, 64, 64, 512)  2048        concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 512)  0           batch_normalization_v1_15[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  1179904     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_16 (Batc (None, 64, 64, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 256)  0           batch_normalization_v1_16[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_17 (Batc (None, 64, 64, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 256)  0           batch_normalization_v1_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 131200      activation_17[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           activation_5[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_18 (Batc (None, 128, 128, 256 1024        concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 128, 128, 256 0           batch_normalization_v1_18[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 295040      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_19 (Batc (None, 128, 128, 128 512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 128, 128, 128 0           batch_normalization_v1_19[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 147584      activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_20 (Batc (None, 128, 128, 128 512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 128, 128, 128 0           batch_normalization_v1_20[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 32832       activation_20[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           activation_3[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_21 (Batc (None, 256, 256, 128 512         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 256, 256, 128 0           batch_normalization_v1_21[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 64) 73792       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_22 (Batc (None, 256, 256, 64) 256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 256, 256, 64) 0           batch_normalization_v1_22[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 36928       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_23 (Batc (None, 256, 256, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 256, 256, 64) 0           batch_normalization_v1_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 512, 512, 32) 8224        activation_23[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 512, 512, 64) 0           activation_1[0][0]
#                                                                  conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_24 (Batc (None, 512, 512, 64) 256         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 512, 512, 64) 0           batch_normalization_v1_24[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 512, 512, 32) 18464       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_25 (Batc (None, 512, 512, 32) 128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 512, 512, 32) 0           batch_normalization_v1_25[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 512, 512, 32) 9248        activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_26 (Batc (None, 512, 512, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 512, 512, 32) 0           batch_normalization_v1_26[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 512, 512, 1)  33          activation_26[0][0]
# ==================================================================================================
# Total params: 31,127,937
# Trainable params: 31,111,937
# Non-trainable params: 16,000
# __________________________________________________________________________________________________

# %%
save_model_path = r'C:\Users\yan\Documents\CT'
cp = tf.keras.callbacks.ModelCheckpoint(filepath=save_model_path, monitor='val_dice_loss', save_best_only=True, verbose=1)

# %%
history = model.fit(train_ds, 
                   steps_per_epoch=int(np.ceil(num_train_examples / float(batch_size))),
                   epochs=epochs,
                   validation_data=val_ds,
                   validation_steps=int(np.ceil(num_val_examples / float(batch_size))),
                   callbacks=[cp])

# %%
dice = history.history['dice_loss']
val_dice = history.history['val_dice_loss']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, dice, label='Training Dice Loss')
plt.plot(epochs_range, val_dice, label='Validation Dice Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Dice Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()
